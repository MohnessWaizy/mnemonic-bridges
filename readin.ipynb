# %%
import numpy as np
import pandas as pd

# %%
_data = pd.read_csv("./res/data/lemmas.txt", delimiter="\t")
_data.head()
# Out:
#    rank  wordID  word PoS  frequency  range  range10  caps
# 0     1       1   the   a  746240010    1.0     1.00  0.11
# 1    11      10   you   p  131299336    1.0     0.99  0.12
# 2    21      20  will   v   58588289    1.0     1.00  0.01
# 3    31      30    as   c   40335062    1.0     1.00  0.11
# 4    41      37   use   v   33469467    1.0     0.98  0.06

# %%
_data["PoS"].unique()
# Out:
# array(['a', 'p', 'v', 'c', 'n', 'e', 'i', 'j', 'd', 'm', 'r', 'u'],
#       dtype=object)
